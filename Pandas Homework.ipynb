# %%
import pandas as pd
import numpy as np

file_to_load = "Resources/purchase_data.csv"

purchase_data = pd.read_csv(file_to_load)

# %%
allPlayers = len(purchase_data["SN"])

# %%
players = len(purchase_data["SN"].unique())

# %%
players_df = pd.DataFrame([{"Total Players": players}])

# %%
players_df
# Out:
#    Total Players
# 0            576

# %%
playerList = purchase_data.loc[:, ["Gender", "SN", "Age"]]
playerList = purchase_data.drop_duplicates(subset=["SN"], keep="first")
playerList
# Out:
#      Purchase ID              SN  Age                 Gender  Item ID  \
# 0              0         Lisim78   20                   Male      108
# 1              1     Lisovynya38   40                   Male      143
# 2              2      Ithergue48   24                   Male       92
# 3              3   Chamassasya86   24                   Male      100
# 4              4       Iskosia90   23                   Male      131
# 5              5         Yalae81   22                   Male       81
# 6              6       Itheria73   36                   Male      169
# 7              7     Iskjaskst81   20                   Male      162
# 8              8       Undjask33   22                   Male       21
# 9              9     Chanosian48   35  Other / Non-Disclosed      136
# 10            10       Inguron55   23                   Male       95
# 11            11    Haisrisuir60   23                   Male      162
# ...

# %%
items = len(purchase_data["Item ID"].unique())
avgPrice = purchase_data["Price"].mean()
totalRevenue = purchase_data["Price"].sum()
numberOfPurchases = purchase_data["Price"].count()

# %%
summary_table = pd.DataFrame(columns=["Number of Unique Items",
                                     "Total Revenue",
                                     "Number of Purchases",
                                     "Average Price"])

# %%
summary_table.loc[0] = [
    items,
    totalRevenue,
    numberOfPurchases,
    avgPrice
]
summary_table
# Out:
#    Number of Unique Items  Total Revenue  Number of Purchases  Average Price
# 0                   183.0        2379.77                780.0       3.050987

# %%
genderCount = playerList["Gender"].value_counts()
genderPercentage = genderCount/players * 100

# %%
gender_df = pd.DataFrame({"Total Count": genderCount, "Percentage of Players": genderPercentage})
gender_df
# Out:
#                        Total Count  Percentage of Players
# Male                           484              84.027778
# Female                          81              14.062500
# Other / Non-Disclosed           11               1.909722

# %%
genderPurchaseTotal = purchase_data.groupby(["Gender"]).sum()["Price"]
genderAvgPrice = purchase_data.groupby(["Gender"]).mean()["Price"]
genderPerPerson = genderPurchaseTotal / gender_df["Total Count"]

# %%
genderPerPerson
# Out:
# Female                   4.468395
# Male                     4.065372
# Other / Non-Disclosed    4.562727
# dtype: float64

# %%
#genderPerPesonPurchase =genderPerPerson / genderPurchaseTotal
#avg_per_gen

# %%
avgpurchase_price = avg_per_gen * norm_total
avgpurchase_price

# %%
gender_summary_table = pd.DataFrame({"Purchase Count": gender_df["Total Count"],"Avg Purchase Price": genderAvgPrice, "Purchase Total": genderPurchaseTotal, "Per Person": genderPerPerson})

gender_summary_table
# Out:
#                        Purchase Count  Avg Purchase Price  Purchase Total  \
# Female                             81            3.203009          361.94
# Male                              484            3.017853         1967.64
# Other / Non-Disclosed              11            3.346000           50.19
#
#                        Per Person
# Female                   4.468395
# Male                     4.065372
# Other / Non-Disclosed    4.562727

# %%
bins = [0, 16, 22, 31, 46, 50]
binLabels = ["0 - 15", "16 - 21", "22 - 30", "31 - 45", "45 and Up"]

purchase_data["Age Range"] = pd.cut(purchase_data["Age"], bins, labels=binLabels)
ageCount = purchase_data["Age Range"].value_counts()
agePercentage = ageCount / allPlayers * 100

# %%
age_df = pd.DataFrame({"Age Total": ageCount,
                       "Age Percentage": agePercentage})
age_df
# Out:
#            Age Total  Age Percentage
# 16 - 21          302       38.717949
# 22 - 30          277       35.512821
# 0 - 15           116       14.871795
# 31 - 45           85       10.897436
# 45 and Up          0        0.000000

# %%
purchase_data["Age Range"] = pd.cut(purchase_data["Age"], bins, labels=binLabels)
purchase_data["Age Range"]
# Out:
# 0      16 - 21
# 1      31 - 45
# 2      22 - 30
# 3      22 - 30
# 4      22 - 30
# 5      16 - 21
# 6      31 - 45
# 7      16 - 21
# 8      16 - 21
# 9      31 - 45
# 10     22 - 30
# 11     22 - 30
# 12     16 - 21
# 13     16 - 21
# 14     31 - 45
# 15     16 - 21
# 16     16 - 21
# 17     16 - 21
# 18     16 - 21
# 19     22 - 30
# 20     16 - 21
# 21     16 - 21
# 22     31 - 45
# 23     31 - 45
# 24     22 - 30
# 25     22 - 30
# 26      0 - 15
# 27      0 - 15
# 28     16 - 21
# 29     22 - 30
#         ...
# 750    16 - 21
# 751     0 - 15
# 752    16 - 21
# 753    31 - 45
# 754    22 - 30
# 755     0 - 15
# 756    16 - 21
# 757    16 - 21
# 758    16 - 21
# 759    22 - 30
# 760    16 - 21
# 761    31 - 45
# 762    22 - 30
# 763    16 - 21
# 764    16 - 21
# 765    16 - 21
# 766    22 - 30
# 767     0 - 15
# 768    31 - 45
# 769     0 - 15
# 770    31 - 45
# 771     0 - 15
# 772    22 - 30
# 773    16 - 21
# 774     0 - 15
# 775    16 - 21
# 776    16 - 21
# 777    16 - 21
# ...

# %%
ageRangePurchaseTotals = purchase_data.groupby(["Age Range"]).sum()["Price"]
ageRangeAvgPrice = purchase_data.groupby(["Age Range"]).mean()["Price"]
ageRangePurchases = purchase_data.groupby(["Age Range"]).count()["Price"]

# %%
ageRangeAvgPurchases = ageRangePurchaseTotals / ageRangePurchases

# %%
age_summary_table = pd.DataFrame({"Purchase Count": ageRangePurchases, "Avg Purchase Price": ageRangeAvgPrice, "Purchase Total": ageRangePurchaseTotals, "Avg Purchases": ageRangeAvgPurchases})
age_summary_table
# Out:
#            Purchase Count  Avg Purchase Price  Purchase Total  Avg Purchases
# Age Range
# 0 - 15                116            3.070000          356.12       3.070000
# 16 - 21               302            3.041689          918.59       3.041689
# 22 - 30               277            3.030758          839.52       3.030758
# 31 - 45                85            3.124000          265.54       3.124000
# 45 and Up               0                 NaN            0.00            NaN

# %%
perPlayerPurchaseCount = purchase_data.groupby(["SN"]).count()["Price"]
perPlayerAvgPrice = purchase_data.groupby(["SN"]).mean()["Price"]
perPlayerPurchaseValue = purchase_data.groupby(["SN"]).sum()["Price"]

# %%
perPlayerAvgPrice
# Out:
# SN
# Adairialis76       2.280000
# Adastirin33        4.480000
# Aeda94             4.910000
# Aela59             4.320000
# Aelaria33          1.790000
# Aelastirin39       3.645000
# Aelidru27          1.090000
# Aelin32            2.993333
# Aelly27            3.395000
# Aellynun67         3.740000
# Aellyria80         3.080000
# Aelollo59          2.815000
# Aenarap34          2.960000
# Aeral43            4.400000
# Aeral68            4.000000
# Aeral97            4.800000
# Aeralria27         4.090000
# Aeralstical35      2.960000
# Aeri84             1.610000
# Aerillorin70       3.330000
# Aerithllora36      4.320000
# Aerithnucal56      4.400000
# Aerithnuphos61     4.910000
# Aerithriaphos45    1.560000
# Aerithriaphos46    2.180000
# Aesri53            1.760000
# Aesty53            1.955000
# Aestysu37          2.690000
# Aesur96            2.210000
# Aesurstilis64      1.030000
#                      ...
# Undosia27          3.770000
# Undosian34         4.150000
# ...

# %%
player_summary_table = pd.DataFrame({"Purchases Count": perPlayerPurchaseCount, "Avg Purchase Price": perPlayerAvgPrice, "Purchase Total": perPlayerPurchaseValue})
player_summary_table
# Out:
#                  Purchases Count  Avg Purchase Price  Purchase Total
# SN
# Adairialis76                   1            2.280000            2.28
# Adastirin33                    1            4.480000            4.48
# Aeda94                         1            4.910000            4.91
# Aela59                         1            4.320000            4.32
# Aelaria33                      1            1.790000            1.79
# Aelastirin39                   2            3.645000            7.29
# Aelidru27                      1            1.090000            1.09
# Aelin32                        3            2.993333            8.98
# Aelly27                        2            3.395000            6.79
# Aellynun67                     1            3.740000            3.74
# Aellyria80                     1            3.080000            3.08
# Aelollo59                      2            2.815000            5.63
# Aenarap34                      1            2.960000            2.96
# ...

# %%
sort here

# %%
itemPurchaseCount = purchase_data.groupby(["Item ID", "Item Name"]).count()["Price"]
itemPrice = purchase_data.groupby(["Item ID", "Item Name"]).mean()["Price"]
itemPurchaseTotal = purchase_data.groupby(["Item ID", "Item Name"]).sum()["Price"]

# %%
item_summary_table = pd.DataFrame({"Purchase Count": itemPurchaseCount,"Avg Purchase Price": itemPrice,"Purchase Total": itemPurchaseTotal})


item_summary_table
# Out:
#                                                       Purchase Count  \
# Item ID Item Name
# 0       Splinter                                                   4
# 1       Crucifer                                                   3
# 2       Verdict                                                    6
# 3       Phantomlight                                               6
# 4       Bloodlord's Fetish                                         5
# 5       Putrid Fan                                                 4
# 6       Rusty Skull                                                2
# 7       Thorn, Satchel of Dark Souls                               7
# 8       Purgatory, Gem of Regret                                   3
# 9       Thorn, Conqueror of the Corrupted                          4
# 10      Sleepwalker                                                4
# 11      Brimstone                                                  5
# ...

# %%
mostPopular = item_summary_table.sort_values("Purchase Count", ascending=False).head(5)
mostPopular
# Out:
#                                                       Purchase Count  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm              12
# 145     Fiery Glass Crusader                                       9
# 108     Extraction, Quickblade Of Trembling Hands                  9
# 82      Nirvana                                                    9
# 19      Pursuit, Cudgel of Necromancy                              8
#
#                                                       Avg Purchase Price  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm                4.23
# 145     Fiery Glass Crusader                                        4.58
# 108     Extraction, Quickblade Of Trembling Hands                   3.53
# 82      Nirvana                                                     4.90
# 19      Pursuit, Cudgel of Necromancy                               1.02
#
#                                                       Purchase Total
# ...

# %%
mostProfitable = item_summary_table.sort_values("Purchase Total", ascending=False).head(5)
mostProfitable
# Out:
#                                                       Purchase Count  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm              12
# 82      Nirvana                                                    9
# 145     Fiery Glass Crusader                                       9
# 92      Final Critic                                               8
# 103     Singed Scalpel                                             8
#
#                                                       Avg Purchase Price  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm                4.23
# 82      Nirvana                                                     4.90
# 145     Fiery Glass Crusader                                        4.58
# 92      Final Critic                                                4.88
# 103     Singed Scalpel                                              4.35
#
#                                                       Purchase Total
# ...
